# %% [markdown]
# # MIT-GSL Uruguay
#
# ## January 2020

# %% [markdown]
# -----

# %% [markdown]
# # Week - 2 | Lesson - 04
# # NLP: Product embeddings in Keras

# %% [markdown]
# 1. After introducing the concept of embeddings through NLP, we extend the notion of embeddings to other settings
# 2. Note that embeddings are dense continuous representations for discrete, sparse tokens - this makes embeddings widely applicable
# 3. We will use the concept of embeddings to understand the world of e-commerce better

# %% [markdown]
# ---

# %% [markdown]
# # Word2Vec and its Applications to Market-Basket Data

# %% [markdown]
# # Instacart Grocery Dataset
#
# ### Source: https://www.instacart.com/datasets/grocery-shopping-2017
#
# 1. Instacart is an online grocery delivery service
# 2. They have made available 3M grocery orders for over 200K users
# 3. They provide between 4 to 100 orders for each user and each order contains the sequence of products purchased
# 4. We also have a brief description of the products
#
# ### Overview:
# 1. We will use this data to build an understanding of word embeddings and investigate their application to downstream tasks
# 2. For this purpose, we will consider each purchase basket to be a sentence with an unordered sequence of words

# %% [markdown]
# ---

# %% [markdown]
# # 0. Import Modules

# %%
# ==============================================
# 0. Module imports
# ==============================================

import pandas as pd
pd.options.display.max_colwidth = 100
import numpy as np
from itertools import product
import csv
import collections
import random

# w2v
import gensim

# text processing
from nltk import sent_tokenize, word_tokenize
from nltk.tokenize import ToktokTokenizer
import string
import re # regular expressions
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics.pairwise import cosine_similarity

# T-Sne
#import umap
#from openTSNE import TSNE, TSNEEmbedding, affinity, initialization
#from openTSNE import initialization
#from openTSNE.callbacks import ErrorLogger
from sklearn.manifold import TSNE


# utils
from sklearn import utils


# parallel processing
import multiprocessing
from joblib import delayed, Parallel

# time code
import time

# 2-d visualiztion
# %matplotlib inline
from ggplot import *
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

import os

import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# ===============================================
# keras modules
# ===============================================

from keras.models import Model
from keras.models import Sequential
from keras.layers import Input, Dense, Reshape, merge, Flatten, Concatenate, Activation, Multiply
from keras.layers.embeddings import Embedding
from keras.layers.merge import dot
from keras.layers.merge import Dot
from keras.preprocessing.sequence import skipgrams
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras import optimizers
from keras.callbacks import History 
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
# =========================================================
# set directories
# =========================================================

import os
EC2 = True  # If using EC2 (for data directory/paths)

# Select path based off of local or remote
if not EC2:
    wd = "/pool001/madhavk/gsl-uruguay/W-02-NLP/"
else:
    wd = "/home/ubuntu/machine_learning_aws/"
os.chdir(wd)

if not EC2:
    # raw data
    raw_data_dir = "nlp-data/in-grocery/instacart_2017_05_01/"
    # processed data
    process_dir = "nlp-data/in-grocery/prepared-data/"  
else:
    # raw data
    raw_data_dir = "data/in-grocery/instacart_2017_05_01"
    # processed data
    process_dir = "data/in-grocery/prepared-data/"

# %%
#===============================================
# processed files
#===============================================
os.listdir(process_dir)
# Out:
# ['orders-split-v1.csv',
#  'all-orders-wide-v1.csv',
#  'all-orders-long-v1.csv',
#  'products-merged-v1.csv']

# %%
#===============================================
# global parameters
#===============================================

# show entire value of cell in pandas
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', 500)

# number of cpus
cpus = multiprocessing.cpu_count()
f"Number of CPUs: {cpus}"
# Out:
# 'Number of CPUs: 4'

# %% [markdown]
# ---

# %% [markdown]
# # 1. Prepare data

# %%
# start pool process for parallel procressing
pool = multiprocessing.Pool(processes = cpus)

# %%
# =========================================================
# order-level data
# =========================================================

orders_wide = pd.read_csv(process_dir + "all-orders-wide-v1.csv")
print(orders_wide.shape)

# =========================================================
# orders meta-data
# =========================================================

orders_meta = pd.read_csv(process_dir + "orders-split-v1.csv")
print(orders_meta.shape)

# =========================================================
# merge orders-wide and orders-meta
# =========================================================

orders_wide.drop(labels = "eval", axis = 1, inplace = True)

# merge
orders_wide = pd.merge(orders_wide, orders_meta[["order_id", "user_id", "eval"]],
                       on = "order_id", how = "left")
print(orders_wide.shape)

# clear some space
del orders_meta


# product info data
products = pd.read_csv(process_dir + "products-merged-v1.csv")
print(products.shape)
products["product_id"] = products["product_id"].astype(str)

#===============================================
# split train-val-test
#===============================================

train = orders_wide.loc[orders_wide["eval"].isin(["prior", "train"]), :]
val = orders_wide.loc[orders_wide["eval"] == "val", :]
test = orders_wide.loc[orders_wide["eval"] == "test", :]
print("train size:", train.shape)
print("val size:", val.shape)
print("test size:", test.shape)

# clear more space
del orders_wide

#===============================================
# randomly sample training data
#===============================================

sample_size = 1000000
train = train.sample(n = sample_size)
train = train.reset_index(drop = True)
print(train.shape)

# training sentences
t0 = time.time()
train_orders = pool.map(word_tokenize, train["product_id"])
t1 = time.time()
print(len(train_orders))

# validation sentences
t0 = time.time()
val_orders = pool.map(word_tokenize, val["product_id"])
t1 = time.time()
print(len(val_orders))

# test sentences
t0 = time.time()
test_orders = pool.map(word_tokenize, test["product_id"])
t1 = time.time()
print(len(test_orders))
# Out:
# (3152555, 4)
# (3346083, 7)
# (3152555, 5)
# (49688, 6)
# train size: (3075412, 5)
# val size: (38701, 5)
# test size: (38442, 5)
# (1000000, 5)
# 1000000
# 38701
# 38442

# %% [markdown]
# ## Current state of data

# %%
display(train.head())
# Out:
#    order_id  \
# 0  2465867
# 1  737422
# 2  616819
# 3  3156340
# 4  369147
#
#                                                                              product_id  \
# 0  6184 17122 11266 13176 32303
# 1  14148 48131 9783 24852 45453 9261 6991 10305 8138 24826 27471 27104 24129 5438 21616
# 2  46516 9934 43744 21903 34969 47626 42828 33401 13984 34126 22825 46969 34243 43789
# 3  19057 1374
# 4  2361 20410
#
#    num_products  user_id   eval
# 0  5             66150    prior
# 1  15            139501   prior
# 2  14            111295   prior
# 3  2             189304   prior
# 4  2             88820    prior

# %%
train["product_id"][0:3]
# Out:
# 0    6184 17122 11266 13176 32303
# 1    14148 48131 9783 24852 45453 9261 6991 10305 8138 24826 27471 27104 24129 5438 21616
# 2    46516 9934 43744 21903 34969 47626 42828 33401 13984 34126 22825 46969 34243 43789
# Name: product_id, dtype: object

# %%
train_orders[0:3]
# Out:
# [['6184', '17122', '11266', '13176', '32303'],
#  ['14148',
#   '48131',
#   '9783',
#   '24852',
#   '45453',
#   '9261',
#   '6991',
#   '10305',
#   '8138',
#   '24826',
#   '27471',
#   '27104',
#   '24129',
#   '5438',
#   '21616'],
#  ['46516',
#   '9934',
#   '43744',
#   '21903',
#   '34969',
#   '47626',
#   '42828',
#   '33401',
#   '13984',
#   '34126',
#   '22825',
#   '46969',
#   '34243',
#   '43789']]

# %% [markdown]
# ### In-class exercise

# %%
# Print the first 3 rows of val

# %%
# Print the first 3 elements of list val_orders

# %% [markdown]
# ----

# %% [markdown]
# # 2. Writing our own Word2Vec in Keras

# %% [markdown]
# - We are now going to train product embeddings in Keras + Tensorflow
# - In order to this, we need to transform the data in a format that Keras/Tensorflow will accept

# %% [markdown]
# ## Tasks:
# ### 1. Count frequency of all words in dataset
#      1.1. Used to sample words based on frequency
# ### 2. Create word-to-index dictionary
#     2.1. The index for each word serves as a lookup value in the embedding matrix
#     2.2. The dictionary is created in order of frequency
# ### 3. Convert entire dataset from a sequence of words to a sequences of indices

# %% [markdown]
# ---

# %% [markdown]
# ## 2.1. Count frequency of each word in vocabulary

# %%
def WordFrequency(train_data, max_words = 10000):
    '''
    Assumes train data is a list of lists
    '''
    train_flat = [item for sublist in train_data for item in sublist] 
    count = [['UNK', -1]]
    count.extend(collections.Counter(train_flat).most_common(max_words))
    return count

# %%
# flatten train-orders to create one giant list
word_freq = WordFrequency(train_data = train_orders)
len(word_freq)
# Out:
# 10001

# %%
# inspect
word_freq[0:5]
# Out:
# [['UNK', -1],
#  ('24852', 155084),
#  ('13176', 124261),
#  ('21137', 86883),
#  ('21903', 79556)]

# %% [markdown]
# ----

# %% [markdown]
# ## 2.2. Create Word-to-Index and Index-to-Word dictionaries
# ### 2.2.1. These are used to create look-up embedding matrices
# ### 2.2.2. They are ordered as per frequency of the corresponding word in the vocabulary

# %%
# create word-index dictionary
def Word2Index(word_count):
    dictionary = dict()
    for word, _ in word_count:
        dictionary[word] = len(dictionary)
    # index-word reveresed dictionary
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reversed_dictionary

# %%
word_ix, ix_word = Word2Index(word_count = word_freq)

# %%
word_ix
# Out:
# {'UNK': 0,
#  '24852': 1,
#  '13176': 2,
#  '21137': 3,
#  '21903': 4,
#  '47209': 5,
#  '47766': 6,
#  '47626': 7,
#  '16797': 8,
#  '26209': 9,
#  '27845': 10,
#  '27966': 11,
#  '22935': 12,
#  '24964': 13,
#  '45007': 14,
#  '39275': 15,
#  '49683': 16,
#  '28204': 17,
#  '5876': 18,
#  '40706': 19,
#  '8277': 20,
#  '4920': 21,
#  '30391': 22,
#  '45066': 23,
#  '42265': 24,
#  '19057': 25,
#  '49235': 26,
#  '44632': 27,
#  '37646': 28,
#  '17794': 29,
#  '4605': 30,
#  '21616': 31,
#  '30489': 32,
#  '27104': 33,
#  '31717': 34,
#  '27086': 35,
#  '46979': 36,
#  '44359': 37,
#  '8518': 38,
#  '28985': 39,
#  '41950': 40,
#  '26604': 41,
#  '5077': 42,
#  '34126': 43,
#  '22035': 44,
#  '39877': 45,
#  '10749': 46,
#  '35951': 47,
#  '43352': 48,
#  '21938': 49,
#  '9076': 50,
#  '43961': 51,
#  '24184': 52,
#  '34969': 53,
#  '19660': 54,
#  '48679': 55,
#  '46667': 56,
#  '39928': 57,
#  '31506': 58,
#  '25890': 59,
#  '24838': 60,
#  '12341': 61,
#  '22825': 62,
#  '5450': 63,
#  '5785': 64,
#  '35221': 65,
#  '28842': 66,
#  '33731': 67,
#  '27521': 68,
#  '19125': 987,
#  '22556': 988,
#  '9018': 989,
#  '10326': 990,
#  '26172': 991,
#  '43014': 992,
#  '23339': 993,
#  '10106': 994,
#  '2480': 995,
#  '31635': 996,
#  '27020': 997,
#  '7746': 998,
#  '12572': 999,
#  ...}

# %%
ix_word
# Out:
# {0: 'UNK',
#  1: '24852',
#  2: '13176',
#  3: '21137',
#  4: '21903',
#  5: '47209',
#  6: '47766',
#  7: '47626',
#  8: '16797',
#  9: '26209',
#  10: '27845',
#  11: '27966',
#  12: '22935',
#  13: '24964',
#  14: '45007',
#  15: '39275',
#  16: '49683',
#  17: '28204',
#  18: '5876',
#  19: '40706',
#  20: '8277',
#  21: '4920',
#  22: '30391',
#  23: '45066',
#  24: '42265',
#  25: '19057',
#  26: '49235',
#  27: '44632',
#  28: '37646',
#  29: '17794',
#  30: '4605',
#  31: '21616',
#  32: '30489',
#  33: '27104',
#  34: '31717',
#  35: '27086',
#  36: '46979',
#  37: '44359',
#  38: '8518',
#  39: '28985',
#  40: '41950',
#  41: '26604',
#  42: '5077',
#  43: '34126',
#  44: '22035',
#  45: '39877',
#  46: '10749',
#  47: '35951',
#  48: '43352',
#  49: '21938',
#  50: '9076',
#  51: '43961',
#  52: '24184',
#  53: '34969',
#  54: '19660',
#  55: '48679',
#  56: '46667',
#  57: '39928',
#  58: '31506',
#  59: '25890',
#  60: '24838',
#  61: '12341',
#  62: '22825',
#  63: '5450',
#  64: '5785',
#  65: '35221',
#  66: '28842',
#  67: '33731',
#  68: '27521',
#  69: '8424',
#  70: '44142',
#  71: '20114',
#  72: '8174',
#  73: '33198',
#  74: '27344',
#  75: '29487',
#  76: '11520',
#  77: '18465',
#  78: '15290',
#  79: '28199',
#  80: '46906',
#  81: '9839',
#  82: '27156',
#  83: '43122',
#  84: '3957',
#  85: '23909',
#  86: '34358',
#  87: '4799',
#  88: '16759',
#  89: '9387',
#  90: '42736',
#  91: '38689',
#  92: '41787',
#  93: '4210',
#  94: '47144',
#  95: '41220',
#  96: '7781',
#  97: '33000',
#  98: '196',
#  99: '21709',
#  100: '20995',
#  101: '40604',
#  102: '19678',
#  103: '24489',
#  104: '34243',
#  105: '30233',
#  106: '37687',
#  107: '42828',
#  108: '5479',
#  109: '16185',
#  110: '432',
#  111: '17948',
#  112: '42768',
#  113: '33754',
#  114: '6184',
#  115: '8193',
#  116: '26369',
#  117: '19348',
#  118: '14992',
#  119: '42585',
#  120: '14947',
#  121: '22963',
#  122: '28849',
#  123: '8021',
#  124: '1463',
#  125: '21405',
#  126: '42701',
#  127: '25659',
#  128: '41844',
#  129: '5025',
#  130: '46676',
#  131: '31343',
#  132: '43295',
#  133: '43789',
#  134: '38293',
#  135: '11777',
#  136: '36011',
#  137: '20842',
#  138: '39475',
#  139: '2295',
#  140: '32655',
#  141: '32689',
#  142: '13870',
#  143: '46802',
#  144: '25146',
#  145: '31553',
#  146: '18531',
#  147: '5212',
#  148: '260',
#  149: '39408',
#  150: '10246',
#  151: '36695',
#  152: '38383',
#  153: '24830',
#  154: '1940',
#  155: '43768',
#  156: '11182',
#  157: '18362',
#  158: '6046',
#  159: '21288',
#  160: '18523',
#  161: '44683',
#  162: '29987',
#  163: '890',
#  164: '38777',
#  165: '38159',
#  166: '38456',
#  167: '30450',
#  168: '7948',
#  169: '43772',
#  170: '23734',
#  171: '44910',
#  172: '46969',
#  173: '26620',
#  174: '47734',
#  175: '47672',
#  176: '4957',
#  177: '44987',
#  178: '40310',
#  179: '30776',
#  180: '16349',
#  181: '14678',
#  182: '23375',
#  183: '26165',
#  184: '44422',
#  185: '35939',
#  186: '16953',
#  187: '2078',
#  188: '28289',
#  189: '13984',
#  190: '48364',
#  191: '39812',
#  192: '29447',
#  193: '23165',
#  194: '19048',
#  195: '33787',
#  196: '41290',
#  197: '33120',
#  198: '17600',
#  199: '28465',
#  200: '32864',
#  201: '35108',
#  202: '31683',
#  203: '26940',
#  204: '37067',
#  205: '8859',
#  206: '37158',
#  207: '18370',
#  208: '45',
#  209: '24799',
#  210: '26283',
#  211: '35547',
#  212: '43713',
#  213: '41665',
#  214: '2966',
#  215: '2086',
#  216: '40396',
#  217: '10957',
#  218: '25931',
#  219: '40571',
#  220: '10132',
#  221: '3952',
#  222: '15937',
#  223: '38739',
#  224: '45535',
#  225: '18027',
#  226: '1158',
#  227: '42450',
#  228: '13629',
#  229: '7021',
#  230: '43154',
#  231: '20119',
#  232: '42342',
#  233: '48745',
#  234: '21019',
#  235: '34050',
#  236: '48205',
#  237: '39619',
#  238: '17461',
#  239: '34448',
#  240: '45603',
#  241: '45633',
#  242: '32478',
#  243: '31040',
#  244: '30169',
#  245: '40174',
#  246: '13646',
#  247: '17872',
#  248: '5818',
#  249: '36865',
#  250: '21267',
#  251: '38400',
#  252: '26790',
#  253: '46654',
#  254: '39984',
#  255: '14084',
#  256: '12206',
#  257: '28934',
#  258: '33768',
#  259: '37766',
#  260: '21376',
#  261: '329',
#  262: '32734',
#  263: '5646',
#  264: '6187',
#  265: '23288',
#  266: '43086',
#  267: '42356',
#  268: '6104',
#  269: '18441',
#  270: '6348',
#  271: '48775',
#  272: '39180',
#  273: '39993',
#  274: '10673',
#  275: '25340',
#  276: '19508',
#  277: '10017',
#  278: '13829',
#  279: '42244',
#  280: '40709',
#  281: '651',
#  282: '13535',
#  283: '27336',
#  284: '47977',
#  285: '6873',
#  286: '28156',
#  287: '11782',
#  288: '49075',
#  289: '19677',
#  290: '13249',
#  291: '36070',
#  292: '27695',
#  293: '49520',
#  294: '49383',
#  295: '24561',
#  296: '16083',
#  297: '30720',
#  298: '7963',
#  299: '40545',
#  300: '11422',
#  301: '17795',
#  302: '35921',
#  303: '25588',
#  304: '24024',
#  305: '40199',
#  306: '36550',
#  307: '8571',
#  308: '31915',
#  309: '35561',
#  310: '35042',
#  311: '3599',
#  312: '17122',
#  313: '42625',
#  314: '42445',
#  315: '19019',
#  316: '20082',
#  317: '23537',
#  318: '30827',
#  319: '8670',
#  320: '1511',
#  321: '44449',
#  322: '21295',
#  323: '33401',
#  324: '2825',
#  325: '19706',
#  326: '9339',
#  327: '4562',
#  328: '17706',
#  329: '5194',
#  330: '18288',
#  331: '15872',
#  332: '16965',
#  333: '25466',
#  334: '2855',
#  335: '8048',
#  336: '40723',
#  337: '7751',
#  338: '13380',
#  339: '22395',
#  340: '14233',
#  341: '28993',
#  342: '3376',
#  343: '21195',
#  344: '38164',
#  345: '46720',
#  346: '40332',
#  347: '40516',
#  348: '4472',
#  349: '44570',
#  350: '15902',
#  351: '33129',
#  352: '21174',
#  353: '13740',
#  354: '35140',
#  355: '29662',
#  356: '7175',
#  357: '45200',
#  358: '12916',
#  359: '5782',
#  360: '12456',
#  361: '13166',
#  362: '5134',
#  363: '10644',
#  364: '19691',
#  365: '7503',
#  366: '39561',
#  367: '38928',
#  368: '46584',
#  369: '3464',
#  370: '20955',
#  371: '13575',
#  372: '22124',
#  373: '4421',
#  374: '37029',
#  375: '36735',
#  376: '35898',
#  377: '32691',
#  378: '13198',
#  379: '7559',
#  380: '44560',
#  381: '43662',
#  382: '44765',
#  383: '42719',
#  384: '1025',
#  385: '11408',
#  386: '18234',
#  387: '18918',
#  388: '18811',
#  389: '35628',
#  390: '10070',
#  391: '28745',
#  392: '5258',
#  393: '26384',
#  394: '23029',
#  395: '14197',
#  396: '34262',
#  397: '25138',
#  398: '3896',
#  399: '45123',
#  400: '32433',
#  401: '9092',
#  402: '46820',
#  403: '37710',
#  404: '47141',
#  405: '17949',
#  406: '24954',
#  407: '37220',
#  408: '35503',
#  409: '41065',
#  410: '11140',
#  411: '1999',
#  412: '21292',
#  413: '25824',
#  414: '47042',
#  415: '43504',
#  416: '21333',
#  417: '28476',
#  418: '5456',
#  419: '46616',
#  420: '15613',
#  421: '27730',
#  422: '44628',
#  423: '39947',
#  424: '38273',
#  425: '27548',
#  426: '21573',
#  427: '39190',
#  428: '35535',
#  429: '48628',
#  430: '47759',
#  431: '14161',
#  432: '1194',
#  433: '15424',
#  434: '8309',
#  435: '11068',
#  436: '24841',
#  437: '14462',
#  438: '38768',
#  439: '29307',
#  440: '5322',
#  441: '16696',
#  442: '9825',
#  443: '26800',
#  444: '42110',
#  445: '49175',
#  446: '27323',
#  447: '28601',
#  448: '1244',
#  449: '20734',
#  450: '21386',
#  451: '7969',
#  452: '2314',
#  453: '13517',
#  454: '2452',
#  455: '2228',
#  456: '27744',
#  457: '11005',
#  458: '22474',
#  459: '12980',
#  460: '27796',
#  461: '31066',
#  462: '9020',
#  463: '49191',
#  464: '41658',
#  465: '4086',
#  466: '32177',
#  467: '20345',
#  468: '5161',
#  469: '26497',
#  470: '3298',
#  471: '41588',
#  472: '20738',
#  473: '21927',
#  474: '19173',
#  475: '18479',
#  476: '13733',
#  477: '15261',
#  478: '16521',
#  479: '5769',
#  480: '22959',
#  481: '27325',
#  482: '22849',
#  483: '20574',
#  484: '5373',
#  485: '17316',
#  486: '44799',
#  487: '36724',
#  488: '33055',
#  489: '21872',
#  490: '4656',
#  491: '12845',
#  492: '37524',
#  493: '47630',
#  494: '35887',
#  495: '6948',
#  496: '48697',
#  497: '17758',
#  498: '18963',
#  499: '21543',
#  500: '34584',
#  501: '25513',
#  502: '35914',
#  503: '11712',
#  504: '49131',
#  505: '40198',
#  506: '31720',
#  507: '18926',
#  508: '15649',
#  509: '45104',
#  510: '23543',
#  511: '36316',
#  512: '30406',
#  513: '26348',
#  514: '44661',
#  515: '5612',
#  516: '6740',
#  517: '39108',
#  518: '44008',
#  519: '40377',
#  520: '10305',
#  521: '11512',
#  522: '9755',
#  523: '30639',
#  524: '36082',
#  525: '7500',
#  526: '24221',
#  527: '13838',
#  528: '18656',
#  529: '23516',
#  530: '43129',
#  531: '46069',
#  532: '12409',
#  533: '40063',
#  534: '25718',
#  535: '28427',
#  536: '32303',
#  537: '31651',
#  538: '32403',
#  539: '48559',
#  540: '26317',
#  541: '12872',
#  542: '15392',
#  543: '39558',
#  544: '47912',
#  545: '30696',
#  546: '31215',
#  547: '2450',
#  548: '39581',
#  549: '7628',
#  550: '35163',
#  551: '45504',
#  552: '28553',
#  553: '6631',
#  554: '30353',
#  555: '32747',
#  556: '12576',
#  557: '2091',
#  558: '34668',
#  559: '46842',
#  560: '49533',
#  561: '23236',
#  562: '43875',
#  563: '25753',
#  564: '1529',
#  565: '5550',
#  566: '31981',
#  567: '27690',
#  568: '34217',
#  569: '14852',
#  570: '13263',
#  571: '36929',
#  572: '25640',
#  573: '31766',
#  574: '12099',
#  575: '11576',
#  576: '38996',
#  577: '22142',
#  578: '45948',
#  579: '29926',
#  580: '29941',
#  581: '4461',
#  582: '41149',
#  583: '11440',
#  584: '14633',
#  585: '11759',
#  586: '38772',
#  587: '9515',
#  588: '5652',
#  589: '14651',
#  590: '34466',
#  591: '28928',
#  592: '14218',
#  593: '14129',
#  594: '32465',
#  595: '48395',
#  596: '24009',
#  597: '46522',
#  598: '7156',
#  599: '24810',
#  600: '6489',
#  601: '10385',
#  602: '14715',
#  603: '47788',
#  604: '36772',
#  605: '10912',
#  606: '17284',
#  607: '3142',
#  608: '35004',
#  609: '43394',
#  610: '32429',
#  611: '46886',
#  612: '12276',
#  613: '781',
#  614: '17652',
#  615: '4367',
#  616: '41400',
#  617: '4793',
#  618: '18594',
#  619: '29675',
#  620: '40268',
#  621: '31433',
#  622: '8138',
#  623: '17224',
#  624: '5240',
#  625: '2326',
#  626: '42557',
#  627: '311',
#  628: '7485',
#  629: '9808',
#  630: '44479',
#  631: '2846',
#  632: '19006',
#  633: '5068',
#  634: '2120',
#  635: '19816',
#  636: '38200',
#  637: '20940',
#  638: '29127',
#  639: '8555',
#  640: '12745',
#  641: '23405',
#  642: '37119',
#  643: '27243',
#  644: '33043',
#  645: '46149',
#  646: '42460',
#  647: '14901',
#  648: '47792',
#  649: '44234',
#  650: '14870',
#  651: '16254',
#  652: '10831',
#  653: '16616',
#  654: '37065',
#  655: '365',
#  656: '3583',
#  657: '33548',
#  658: '38650',
#  659: '16262',
#  660: '34134',
#  661: '23622',
#  662: '34530',
#  663: '48104',
#  664: '10504',
#  665: '42495',
#  666: '1700',
#  667: '4942',
#  668: '44156',
#  669: '22025',
#  670: '16145',
#  671: '13292',
#  672: '30305',
#  673: '10603',
#  674: '23579',
#  675: '45763',
#  676: '29370',
#  677: '28278',
#  678: '17429',
#  679: '40910',
#  680: '13083',
#  681: '31869',
#  682: '3990',
#  683: '1090',
#  684: '39040',
#  685: '38890',
#  686: '7644',
#  687: '32566',
#  688: '16617',
#  689: '14168',
#  690: '8955',
#  691: '12614',
#  692: '1408',
#  693: '45646',
#  694: '48857',
#  695: '21009',
#  696: '46692',
#  697: '16823',
#  698: '24759',
#  699: '6532',
#  700: '9337',
#  701: '8479',
#  702: '5460',
#  703: '33716',
#  704: '2962',
#  705: '18880',
#  706: '31964',
#  707: '39922',
#  708: '46226',
#  709: '20580',
#  710: '22504',
#  711: '12384',
#  712: '17616',
#  713: '28123',
#  714: '17341',
#  715: '3481',
#  716: '36389',
#  717: '20754',
#  718: '36086',
#  719: '28373',
#  720: '23233',
#  721: '21417',
#  722: '25005',
#  723: '7131',
#  724: '26128',
#  725: '38028',
#  726: '10621',
#  727: '17835',
#  728: '26131',
#  729: '31759',
#  730: '24082',
#  731: '23765',
#  732: '30442',
#  733: '24535',
#  734: '49610',
#  735: '21614',
#  736: '35383',
#  737: '8230',
#  738: '16589',
#  739: '11352',
#  740: '9124',
#  741: '30949',
#  742: '1215',
#  743: '29553',
#  744: '37825',
#  745: '2611',
#  746: '10814',
#  747: '33572',
#  748: '4138',
#  749: '19156',
#  750: '6287',
#  751: '28535',
#  752: '38944',
#  753: '32455',
#  754: '9741',
#  755: '45747',
#  756: '31805',
#  757: '4724',
#  758: '45063',
#  759: '17008',
#  760: '7521',
#  761: '1559',
#  762: '8087',
#  763: '41544',
#  764: '13431',
#  765: '48595',
#  766: '33352',
#  767: '48171',
#  768: '19894',
#  769: '18382',
#  770: '12606',
#  771: '45570',
#  772: '40593',
#  773: '10032',
#  774: '31562',
#  775: '17630',
#  776: '41319',
#  777: '33290',
#  778: '9366',
#  779: '18434',
#  780: '47029',
#  781: '17807',
#  782: '47601',
#  783: '20632',
#  784: '581',
#  785: '19003',
#  786: '23801',
#  787: '14467',
#  788: '18987',
#  789: '42803',
#  790: '9421',
#  791: '13819',
#  792: '47866',
#  793: '23341',
#  794: '38656',
#  795: '8490',
#  796: '7916',
#  797: '3020',
#  798: '22888',
#  799: '39121',
#  800: '11461',
#  801: '27307',
#  802: '47492',
#  803: '17902',
#  804: '46900',
#  805: '34234',
#  806: '6347',
#  807: '5449',
#  808: '46049',
#  809: '11136',
#  810: '43631',
#  811: '39097',
#  812: '31371',
#  813: '15200',
#  814: '29615',
#  815: '27360',
#  816: '24382',
#  817: '29594',
#  818: '45013',
#  819: '5337',
#  820: '9550',
#  821: '46650',
#  822: '24010',
#  823: '17878',
#  824: '22260',
#  825: '8467',
#  826: '41540',
#  827: '8239',
#  828: '46041',
#  829: '47890',
#  830: '44471',
#  831: '24390',
#  832: '9327',
#  833: '37011',
#  834: '28785',
#  835: '41259',
#  836: '31338',
#  837: '34',
#  838: '23296',
#  839: '25837',
#  840: '19488',
#  841: '36127',
#  842: '18564',
#  843: '19478',
#  844: '38544',
#  845: '38274',
#  846: '23645',
#  847: '33636',
#  848: '5618',
#  849: '43643',
#  850: '7806',
#  851: '14778',
#  852: '16290',
#  853: '44514',
#  854: '3849',
#  855: '6615',
#  856: '8736',
#  857: '42240',
#  858: '29898',
#  859: '4149',
#  860: '30480',
#  861: '21497',
#  862: '5959',
#  863: '2180',
#  864: '20520',
#  865: '47357',
#  866: '31663',
#  867: '14897',
#  868: '10761',
#  869: '49111',
#  870: '46061',
#  871: '35233',
#  872: '41593',
#  873: '44375',
#  874: '4137',
#  875: '19049',
#  876: '10473',
#  877: '14999',
#  878: '44292',
#  879: '34551',
#  880: '2716',
#  881: '248',
#  882: '18599',
#  883: '49247',
#  884: '4006',
#  885: '5031',
#  886: '18019',
#  887: '38444',
#  888: '41276',
#  889: '40002',
#  890: '48726',
#  891: '12427',
#  892: '45106',
#  893: '49478',
#  894: '33846',
#  895: '25133',
#  896: '13802',
#  897: '26914',
#  898: '4962',
#  899: '13712',
#  900: '5991',
#  901: '20899',
#  902: '11941',
#  903: '20583',
#  904: '40348',
#  905: '47526',
#  906: '25544',
#  907: '33065',
#  908: '45681',
#  909: '12312',
#  910: '17027',
#  911: '26047',
#  912: '47087',
#  913: '45064',
#  914: '26882',
#  915: '41273',
#  916: '7054',
#  917: '23044',
#  918: '31927',
#  919: '43867',
#  920: '28597',
#  921: '22151',
#  922: '16283',
#  923: '10369',
#  924: '35336',
#  925: '1695',
#  926: '16249',
#  927: '13852',
#  928: '23554',
#  929: '44310',
#  930: '14332',
#  931: '45866',
#  932: '28851',
#  933: '48057',
#  934: '46175',
#  935: '37464',
#  936: '34024',
#  937: '28986',
#  938: '5250',
#  939: '49605',
#  940: '26648',
#  941: '25705',
#  942: '4796',
#  943: '35168',
#  944: '41757',
#  945: '46088',
#  946: '20919',
#  947: '32650',
#  948: '49215',
#  949: '24850',
#  950: '13113',
#  951: '12797',
#  952: '31640',
#  953: '13702',
#  954: '32740',
#  955: '36036',
#  956: '3999',
#  957: '46346',
#  958: '11123',
#  959: '7952',
#  960: '21162',
#  961: '46206',
#  962: '25197',
#  963: '18670',
#  964: '43409',
#  965: '15399',
#  966: '40229',
#  967: '19068',
#  968: '13885',
#  969: '38312',
#  970: '46990',
#  971: '14858',
#  972: '5491',
#  973: '20378',
#  974: '18352',
#  975: '47877',
#  976: '30561',
#  977: '39216',
#  978: '44548',
#  979: '25256',
#  980: '6656',
#  981: '12545',
#  982: '26629',
#  983: '36956',
#  984: '27683',
#  985: '9623',
#  986: '12254',
#  987: '19125',
#  988: '22556',
#  989: '9018',
#  990: '10326',
#  991: '26172',
#  992: '43014',
#  993: '23339',
#  994: '10106',
#  995: '2480',
#  996: '31635',
#  997: '27020',
#  998: '7746',
#  999: '12572',
#  ...}

# %% [markdown]
# ## 2.3. Convert entire data set from text to indices

# %%
# convert data to index
def Data2Index(train_data, word_ix, ret_unk_cnt = False):
    data = list()
    global unk_count
    unk_count = 0
    for order in train_data:
        ord_data = []
        for word in order:
            if word in word_ix:
                index = word_ix[word]
            else:
                index = 0
                unk_count += 1
            ord_data.append(index)
        data.append(ord_data)
    if ret_unk_cnt:
        return(data, unk_count)
    else:
        return(data)

# %%
# training orders
train_orders_ix = Data2Index(train_data = train_orders, word_ix = word_ix, ret_unk_cnt = False)

# %%
train_orders[0:3]
# Out:
# [['6184', '17122', '11266', '13176', '32303'],
#  ['14148',
#   '48131',
#   '9783',
#   '24852',
#   '45453',
#   '9261',
#   '6991',
#   '10305',
#   '8138',
#   '24826',
#   '27471',
#   '27104',
#   '24129',
#   '5438',
#   '21616'],
#  ['46516',
#   '9934',
#   '43744',
#   '21903',
#   '34969',
#   '47626',
#   '42828',
#   '33401',
#   '13984',
#   '34126',
#   '22825',
#   '46969',
#   '34243',
#   '43789']]

# %%
train_orders_ix[0:3]
# Out:
# [[114, 312, 1429, 2, 536],
#  [9506,
#   6043,
#   6450,
#   1,
#   2422,
#   8477,
#   3983,
#   520,
#   622,
#   6236,
#   2359,
#   33,
#   3916,
#   1044,
#   31],
#  [1904, 1488, 3017, 4, 53, 7, 107, 323, 189, 43, 62, 172, 104, 133]]

# %%
# total number of training orders
len(train_orders)
# Out:
# 1000000

# %%
# val orders
val_orders_ix = Data2Index(train_data = val_orders, word_ix = word_ix, ret_unk_cnt = False)
print(len(val_orders_ix))
# Out:
# 38701

# %% [markdown]
# ----

# %% [markdown]
# ### In-class exercise

# %%
# convert all the test orders to indices using the Data2Index() function

# %% [markdown]
# ----

# %% [markdown]
# # A.1: Intro to Neural Networks

# %%
## code to download imdb data and load into memory
import keras_preprocessing
print(keras_preprocessing.__version__)


import numpy as np
old = np.load
np.load = lambda *a,**k: old(*a,**k,allow_pickle=True)
# call load_data with allow_pickle implicitly set to true
from keras.datasets import imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
np.load = old
del(old)
# Out:
# 1.1.0
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-203-60435693095d> in <module>
#       9 # call load_data with allow_pickle implicitly set to true
#      10 from keras.datasets import imdb
# ---> 11 (x_train, y_train), (x_test, y_test) = imdb.load_data(path='./home/ubuntu/',num_words=10000)
#      12 np.load = old
#      13 del(old)
#
# ~/conda/envs/conda_env/lib/python3.6/site-packages/keras/datasets/imdb.py in load_data(path, num_words, skip_top, maxlen, seed, start_char, oov_char, index_from, **kwargs)
#      55     path = get_file(path,
#      56                     origin='https://s3.amazonaws.com/text-datasets/imdb.npz',
# ---> 57                     file_hash='599dadb1135973df5b59232a0e9a887c')
#      58     with np.load(path) as f:
#      59         x_train, labels_train = f['x_train'], f['y_train']
#
# ~/conda/envs/conda_env/lib/python3.6/site-packages/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     220         try:
#     221             try:
# --> 222                 urlretrieve(origin, fpath, dl_progress)
#     223             except HTTPError as e:
#     224                 raise Exception(error_msg.format(origin, e.code, e.msg))
#
# ~/conda/envs/conda_env/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     256         # Handle temporary file setup.
#     257         if filename:
# --> 258             tfp = open(filename, 'wb')
#     259         else:
#     260             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ubuntu/.keras/datasets/./home/ubuntu/'

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (25000,)
# (25000,)

# %%
x_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
y_train[0:5]
# Out:
# array([1, 0, 0, 1, 0])

# %%
# total number of words
print(max([max(sequence) for sequence in x_train]))
# Out:
# 9999

# %%
# decode back from indices to words
word_index = imdb.get_word_index()

# %%
# reverse the word index by mapping indices to words
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in x_train[0]])
print(decoded_review)
# Out:
# ? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

# %%
x_train = vectorize_sequences(x_train)
x_test = vectorize_sequences(x_test)

# %%
print(len(x_train[0]))
# Out:
# 10000

# %%
print(len(x_test[0]))
# Out:
# 10000

# %%
y_train = np.asarray(y_train).astype('float32')
y_test = np.asarray(y_test).astype('float32')

# %%
from keras import models
from keras import layers

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
from keras import optimizers

# %%
model.compile(optimizer= 'rmsprop',
                      loss= 'binary_crossentropy',
                      metrics= ['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_85 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_86 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_87 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create validation data 
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

# %%
# create validation labels
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs= 9,
                    batch_size= 128,
                    validation_data= (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/9
# 15000/15000 [==============================] - 3s 198us/step - loss: 0.3980 - acc: 0.8405 - val_loss: 0.2830 - val_acc: 0.8895
# Epoch 2/9
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.2103 - acc: 0.9209 - val_loss: 0.2750 - val_acc: 0.8898
# Epoch 3/9
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.1510 - acc: 0.9472 - val_loss: 0.3016 - val_acc: 0.8873
# Epoch 4/9
# 15000/15000 [==============================] - 2s 138us/step - loss: 0.1153 - acc: 0.9595 - val_loss: 0.3424 - val_acc: 0.8834
# Epoch 5/9
# 15000/15000 [==============================] - 2s 138us/step - loss: 0.0855 - acc: 0.9707 - val_loss: 0.3772 - val_acc: 0.8784
# Epoch 6/9
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.0636 - acc: 0.9791 - val_loss: 0.4542 - val_acc: 0.8744
# Epoch 7/9
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.0450 - acc: 0.9843 - val_loss: 0.5012 - val_acc: 0.8728
# Epoch 8/9
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.0315 - acc: 0.9895 - val_loss: 0.6294 - val_acc: 0.8624
# Epoch 9/9
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.0205 - acc: 0.9935 - val_loss: 0.6788 - val_acc: 0.8609

# %%
# plot training and validation accuracy
acc = history.history['acc'] # retreive training accuracy from history
val_acc = history.history['val_acc'] # retreive validation accuracy from history
loss = history.history['loss'] # retreive training loss from history
val_loss = history.history['val_loss'] # retreive validation loss from history

# %%
# two plots - one for loss and the other for accuract
epochs = range(1, len(acc) + 1)

# -- plot 1: Number of epochs vs. accuracy
plt.plot(epochs, acc, 'bo', label= 'Training acc')
plt.plot(epochs, val_acc, 'b', label= 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# -- plot 2: Number of epochs vs. loss
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# # A.2: A slightly larger neural network

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer= 'rmsprop',
                      loss= 'binary_crossentropy',
                      metrics= ['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 32)                320032
# _________________________________________________________________
# dense_89 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_90 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 320,577
# Trainable params: 320,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs= 10,
                    batch_size= 128,
                    validation_data= (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/10
# 15000/15000 [==============================] - 4s 235us/step - loss: 0.4051 - acc: 0.8373 - val_loss: 0.2850 - val_acc: 0.8890
# Epoch 2/10
# 15000/15000 [==============================] - 3s 180us/step - loss: 0.2116 - acc: 0.9209 - val_loss: 0.2811 - val_acc: 0.8902
# Epoch 3/10
# 15000/15000 [==============================] - 3s 179us/step - loss: 0.1514 - acc: 0.9463 - val_loss: 0.3066 - val_acc: 0.8858
# Epoch 4/10
# 15000/15000 [==============================] - 3s 181us/step - loss: 0.1130 - acc: 0.9607 - val_loss: 0.3587 - val_acc: 0.8811
# Epoch 5/10
# 15000/15000 [==============================] - 3s 185us/step - loss: 0.0825 - acc: 0.9711 - val_loss: 0.4174 - val_acc: 0.8747
# Epoch 6/10
# 15000/15000 [==============================] - 3s 183us/step - loss: 0.0561 - acc: 0.9818 - val_loss: 0.4752 - val_acc: 0.8627
# Epoch 7/10
# 15000/15000 [==============================] - 3s 183us/step - loss: 0.0373 - acc: 0.9880 - val_loss: 0.5339 - val_acc: 0.8704
# Epoch 8/10
# 15000/15000 [==============================] - 3s 180us/step - loss: 0.0224 - acc: 0.9934 - val_loss: 0.6061 - val_acc: 0.8648
# Epoch 9/10
# 15000/15000 [==============================] - 3s 181us/step - loss: 0.0126 - acc: 0.9974 - val_loss: 0.7323 - val_acc: 0.8644
# Epoch 10/10
# 15000/15000 [==============================] - 3s 180us/step - loss: 0.0087 - acc: 0.9980 - val_loss: 0.7477 - val_acc: 0.8636

# %%
# plot training and validation accuracy
acc = history.history['acc'] # retreive training accuracy from history
val_acc = history.history['val_acc'] # retreive validation accuracy from history
loss = history.history['loss'] # retreive training loss from history
val_loss = history.history['val_loss'] # retreive validation loss from history

# two plots - one for loss and the other for accuract
epochs = range(1, len(acc) + 1)

# -- plot 1: Number of epochs vs. accuracy
plt.plot(epochs, acc, 'bo', label= 'Training acc')
plt.plot(epochs, val_acc, 'b', label= 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# -- plot 2: Number of epochs vs. loss
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### In-class exercise

# %%
# Build the following neural network:

# 4 layers
# 1. Layer 1: 64 nodes
# 2. Layer 2: 64 nodes
# 3. Layer 3: 32 nodes
# 4. Layer 4: 32 nodes

model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(10000, )))
# model.add(layers.Dense(12, activation='relu'))
# model.add(layers.Dense(4, activation='relu'))
# model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer= 'rmsprop',
                      loss= 'binary_crossentropy',
                      metrics= ['accuracy'])

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs= 5,
                    batch_size= 128,
                    validation_data= (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 3s 227us/step - loss: 0.3868 - acc: 0.8434 - val_loss: 0.3033 - val_acc: 0.8775
# Epoch 2/5
# 15000/15000 [==============================] - 3s 180us/step - loss: 0.2148 - acc: 0.9213 - val_loss: 0.2732 - val_acc: 0.8901
# Epoch 3/5
# 15000/15000 [==============================] - 3s 179us/step - loss: 0.1587 - acc: 0.9434 - val_loss: 0.2926 - val_acc: 0.8854
# Epoch 4/5
# 15000/15000 [==============================] - 3s 178us/step - loss: 0.1239 - acc: 0.9567 - val_loss: 0.3096 - val_acc: 0.8844
# Epoch 5/5
# 15000/15000 [==============================] - 3s 177us/step - loss: 0.1020 - acc: 0.9644 - val_loss: 0.3376 - val_acc: 0.8802

# %%
# plot the accuracy and the loss for training and validation data
# plot training and validation accuracy
acc = history.history['acc'] # retreive training accuracy from history
val_acc = history.history['val_acc'] # retreive validation accuracy from history
loss = history.history['loss'] # retreive training loss from history
val_loss = history.history['val_loss'] # retreive validation loss from history

# two plots - one for loss and the other for accuract
epochs = range(1, len(acc) + 1)

# -- plot 1: Number of epochs vs. accuracy
plt.plot(epochs, acc, 'bo', label= 'Training acc')
plt.plot(epochs, val_acc, 'b', label= 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# -- plot 2: Number of epochs vs. loss
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 3. Define embedding matrices and model

# %% [markdown]
# ## 3.1. Model parameters

# %%
# embedding parameters
vocab_size = len(word_ix)
input_size = vocab_size
emb_size = 100

# %%
# size of vocabulary
f"Vocab size: {vocab_size}"
# Out:
# 'Vocab size: 10001'

# %% [markdown]
# ## 3.2. Embedding layers
# ### We use two embedding layers -- one for the target product and one for the context product

# %%
# define input layers
input_target = Input((1,))
input_target
# Out:
# <tf.Tensor 'input_1:0' shape=(?, 1) dtype=float32>

# %%
input_context = Input((1,))
input_context
# Out:
# <tf.Tensor 'input_2:0' shape=(?, 1) dtype=float32>

# %%
# define embedding layers
# target
target = Embedding(input_dim = vocab_size, output_dim= emb_size, name = "rho")(input_target)
target = Reshape(target_shape = (emb_size, 1))(target)
target
# Out:
# <tf.Tensor 'reshape_1/Reshape:0' shape=(?, 100, 1) dtype=float32>

# %%
# context
context = Embedding(input_dim = vocab_size, output_dim= emb_size, name = "alpha")(input_context)
context = Reshape(target_shape = (emb_size, 1))(context)
context
# Out:
# <tf.Tensor 'reshape_2/Reshape:0' shape=(?, 100, 1) dtype=float32>

# %%
# concatenate model inputs and outputs
input_model = [input_target, input_context]
input_model
# Out:
# [<tf.Tensor 'input_1:0' shape=(?, 1) dtype=float32>,
#  <tf.Tensor 'input_2:0' shape=(?, 1) dtype=float32>]

# %%
output_embeddings = Dot(axes = 1)([target, context])
output_embeddings
# Out:
# <tf.Tensor 'dot_2/MatMul:0' shape=(?, 1, 1) dtype=float32>

# %%
# resize embeddings
#output_model = Reshape((1,))(output_embeddings)
output_model = Flatten()(output_embeddings)
output_model
# Out:
# <tf.Tensor 'flatten_2/Reshape:0' shape=(?, ?) dtype=float32>

# %%
# complete model
output_model = Dense(1, activation = "sigmoid")(output_model)

# %% [markdown]
# ## 3.3. Complete model

# %%
# define as keras model
pemb_model = Model(inputs = input_model, outputs = output_model)
pemb_model

# %%
# optimizer
adam = optimizers.Adam(lr = 0.01, beta_1 = 0.9, beta_2 = 0.999, epsilon = None, decay = 0.0, amsgrad = False)
adam

# %%
# compile model
pemb_model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['acc'])

# %%
# model summary
pemb_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# rho (Embedding)                 (None, 1, 100)       1000100     input_1[0][0]
# __________________________________________________________________________________________________
# alpha (Embedding)               (None, 1, 100)       1000100     input_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 100, 1)       0           rho[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 100, 1)       0           alpha[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1, 1)         0           reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           dot_2[0][0]
# __________________________________________________________________________________________________
# dense_93 (Dense)                (None, 1)            2           flatten_2[0][0]
# ==================================================================================================
# Total params: 2,000,202
# Trainable params: 2,000,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 3.4. Initial product embeddings

# %%
# initial weights - rho
init_alpha = pemb_model.get_layer("alpha").get_weights()[0]
print(init_alpha.shape)
# Out:
# (10001, 100)

# %%
# check the (random) initial embeddings for a product
init_alpha[345]
# Out:
# array([ 0.03836194,  0.02693875, -0.00014309, -0.00601923,  0.01909352,
#         0.01987386, -0.04534608, -0.01405965, -0.02037555, -0.00644739,
#         0.00184913,  0.01026983,  0.03574019, -0.01831882,  0.04597438,
#         0.01574061, -0.02073525,  0.01721774,  0.02392739,  0.00923598,
#         0.02423525,  0.01405642, -0.0095422 ,  0.04956541, -0.00667872,
#         0.04401858,  0.01204485, -0.00485172, -0.01625068,  0.03759321,
#         0.00627965,  0.04871533,  0.03723024, -0.0233688 , -0.00164435,
#        -0.02462182,  0.03824523, -0.03926248,  0.00550016, -0.01998088,
#        -0.00210255,  0.01514957,  0.04095263,  0.02025623,  0.02024747,
#         0.02409334, -0.03295971, -0.02692767, -0.00066981, -0.00856217,
#         0.04669522, -0.0025808 ,  0.02695866,  0.0257207 , -0.02715929,
#         0.02721156,  0.02963176, -0.00470261,  0.04047228,  0.01743983,
#        -0.03762858,  0.0420242 , -0.00127973,  0.0125143 ,  0.01234571,
#         0.04790038,  0.01849233, -0.03010025,  0.02854687,  0.01085415,
#         0.02831462, -0.01919742, -0.03505623, -0.02365385,  0.0217404 ,
#        -0.02285124,  0.03649601, -0.04402984, -0.00982076,  0.01216457,
#        -0.03087593, -0.00434064,  0.01988412,  0.01432982, -0.00159749,
#         0.00247286, -0.01297927, -0.03152683,  0.01503335,  0.03038558,
#         0.00843791, -0.02196573,  0.00378561,  0.0357132 , -0.00970353,
#         0.0254681 , -0.01046716,  0.01977165, -0.00814537,  0.01374239],
#       dtype=float32)

# %% [markdown]
# ----

# %% [markdown]
# # 4. Prepare batches for model

# %%
# sampling table
sampling_table = sequence.make_sampling_table(vocab_size)

# %%
# context size and negative samples
ns = 10.0
cs = 5

# %%
def BatchGenerator(training = True):
    i = 0
    while True:
        if training:
            order_data = random.sample(train_orders_ix, batch_size)
        else:
            order_data = random.sample(val_orders_ix, batch_size)
        iv = []
        dv =[]
        for d in order_data:
            couples, labels = skipgrams(d, vocabulary_size = vocab_size, window_size = cs,
                                        negative_samples = ns, sampling_table = sampling_table)
            iv = iv + couples
            dv = dv + labels
        i += 1
        X = np.array(iv, dtype = "int32")
        X = [X[:, 0], X[:, 1]]
        yield X, dv

# %%
# parameters
batch_size = 64
num_epochs = 1

# training data generator
train_gen = BatchGenerator(training = True)

# validation data generator
val_gen = BatchGenerator(training = False)

# history
history = History()

# %% [markdown]
# ----

# %% [markdown]
# # 5. Train model
# ### This could take a while

# %%
# train model
t0 = time.time()
pemb_model.fit_generator(generator = train_gen, 
                         steps_per_epoch = len(train_orders_ix)//batch_size,
                         epochs = num_epochs,
                         workers = cpus, 
                         use_multiprocessing = True, 
                         validation_data = val_gen,
                         validation_steps = len(val_orders_ix)//batch_size,
                         callbacks = [history])
t1 = time.time()
# Out:
# Epoch 1/1
# 15625/15625 [==============================] - 1062s 68ms/step - loss: 0.2109 - acc: 0.9242 - val_loss: 0.2068 - val_acc: 0.9249

# %%
# time taken
t1 - t0
# Out:
# 1063.1107835769653

# %%
# history
history.history
# Out:
# {'val_loss': [0.20675255598010023],
#  'val_acc': [0.9249407920476108],
#  'loss': [0.21115696218278826],
#  'acc': [0.9241418644349702]}

# %% [markdown]
# ------

# %% [markdown]
# # 6. Model results

# %%
# final weights - target words
final_alpha = pemb_model.get_layer("alpha").get_weights()[0]

# %%
init_alpha[61]
# Out:
# array([-0.0290234 , -0.02148094, -0.01164386, -0.04658482,  0.00242691,
#        -0.00846174,  0.04515902, -0.04913021, -0.00957937, -0.01491904,
#         0.03663868, -0.0427099 ,  0.02908147,  0.00104983, -0.02150297,
#        -0.00169431,  0.03036532,  0.00901666, -0.00631956,  0.00287091,
#         0.03232709, -0.03093532, -0.04663799,  0.03483746,  0.00171681,
#         0.01569153,  0.03561081, -0.04430852, -0.00484533, -0.01301999,
#         0.02845416,  0.03073032, -0.00759572, -0.027659  ,  0.03020147,
#        -0.04547865,  0.03465195,  0.02693136,  0.01428333,  0.03072882,
#        -0.03608263,  0.02123484, -0.02604443, -0.03512935,  0.01646301,
#        -0.01181122, -0.03736176, -0.00988052, -0.03452709,  0.01835593,
#        -0.00780905, -0.01128987, -0.03914608, -0.03347244,  0.01213598,
#         0.01796857, -0.03554822,  0.03428563,  0.0211351 ,  0.04644442,
#         0.03056021,  0.04764744, -0.04207214,  0.02350289, -0.02202759,
#         0.00063331,  0.00967076,  0.02722397, -0.02537973,  0.02452351,
#         0.03056328, -0.00635284, -0.03472441,  0.02260521, -0.01511701,
#         0.04963371,  0.00299686, -0.01921394,  0.03682346,  0.02524108,
#        -0.03659319,  0.01734151,  0.0231748 ,  0.00144301,  0.04979305,
#        -0.02743517, -0.0377908 ,  0.02209545,  0.01604858, -0.01873444,
#         0.04756304, -0.04620457, -0.03026136, -0.00794146, -0.04111394,
#        -0.03233607,  0.03646928,  0.0061977 , -0.04268306, -0.03554649],
#       dtype=float32)

# %%
final_alpha[61]
# Out:
# array([ 9.77202803e-02,  2.19252661e-01,  1.16280246e+00, -1.83208764e+00,
#        -9.90119353e-02, -1.09999263e+00,  2.43877006e+00,  9.99625266e-01,
#        -1.24186002e-01,  1.13587394e-01, -7.31052518e-01, -1.65933883e+00,
#        -1.97117305e+00,  4.88543808e-02,  1.53232443e+00,  1.20742357e+00,
#        -1.04565859e+00, -7.78615415e-01,  1.92904532e-01,  1.23610519e-01,
#         6.97338402e-01,  8.90736103e-01, -1.46755230e+00, -8.92188370e-01,
#        -1.43133819e-01,  9.37507987e-01, -6.10503912e-01,  4.27741140e-01,
#        -2.49255157e+00, -1.88550979e-01, -5.67731440e-01, -1.64463115e+00,
#        -3.01344275e-01, -7.68173814e-01,  5.67389071e-01, -1.20764160e+00,
#        -1.05392063e+00, -2.25512934e+00,  1.44009876e+00,  1.85253310e+00,
#        -1.21211505e+00, -5.49735665e-01,  1.19419122e+00, -1.59083179e-03,
#        -1.79900259e-01,  7.42429376e-01,  5.83652616e-01, -2.30258346e+00,
#         1.28310549e+00, -1.06554151e-01,  2.66222310e+00, -8.67668867e-01,
#         6.91684425e-01,  5.55161417e-01, -1.39889026e+00, -8.91952276e-01,
#        -1.19051278e+00, -1.24671674e+00,  2.01588535e+00, -1.78216517e+00,
#        -7.18085587e-01, -1.03872263e+00,  9.03836191e-02,  7.86751926e-01,
#        -1.43328357e+00, -1.52516961e+00,  2.12028313e+00,  6.57883525e-01,
#        -7.40709186e-01,  1.14761925e+00,  6.83924615e-01, -6.19918764e-01,
#        -1.21313894e+00,  1.82470620e-01,  7.86520302e-01, -1.88070863e-01,
#         4.64926034e-01, -8.06519210e-01, -7.69917905e-01, -5.39837062e-01,
#         7.35044062e-01, -1.04075038e+00, -3.04278284e-01,  7.80416548e-01,
#         5.97451389e-01,  1.12998009e+00,  1.52347386e-01,  1.02374649e+00,
#        -2.45748580e-01,  2.08189607e+00, -6.80549145e-01,  5.52809477e-01,
#        -1.59282589e+00, -1.02217317e+00,  1.06867814e+00, -4.35995907e-01,
#        -1.28141716e-01, -2.16898918e+00, -6.84783608e-02, -2.48989058e+00],
#       dtype=float32)

# %%
#===============================================
# extract embeddings to data frame
#===============================================

def EmbToDataFrame(ix_word, emb_mat, col_prefix = "rho"):
    emb_df = {ix_word[i]: list(emb_mat[i]) for i in ix_word.keys()}
    emb_df = pd.DataFrame.from_dict(emb_df, orient = "columns")
    emb_df = emb_df.transpose().reset_index(drop = False)
    emb_df.columns = ["product_id"] + [col_prefix + str(i + 1) for i in range(emb_df.shape[1] - 1)]
    return emb_df

# %%
# get data frame from alpha matrix
alpha_df = EmbToDataFrame(ix_word, emb_mat = final_alpha, col_prefix = "alpha")
display(alpha_df.head())
# Out:
#   product_id    alpha1    alpha2    alpha3    alpha4    alpha5    alpha6  \
# 0  1         -0.877645 -0.394614 -1.099508 -1.403748  2.036066  0.792116
# 1  10         0.330046 -1.324102 -0.125985  1.825266  0.908763  0.594869
# 2  100       -1.064720 -1.889790  0.017625  0.982703  1.184609  2.408128
# 3  1000      -0.468491 -0.568023 -0.877807 -1.052402 -0.140650  0.387741
# 4  10005      0.465017  0.385074 -0.896616  1.752543 -0.011793  0.407523
#
#      alpha7    alpha8    alpha9   alpha10   alpha11   alpha12   alpha13  \
# 0 -0.015044  1.002345 -2.267114  2.234086  1.723917  1.580796  0.033252
# 1 -1.796393 -0.203477 -0.152604  1.195052  0.018034 -0.351667 -0.212080
# 2 -0.703567  1.803581 -1.774199  0.249306  1.343128  0.621178  0.792283
# 3  0.537068 -0.318927 -0.897438  3.043285 -0.800126  1.003142 -1.198031
# 4 -1.348540  0.268913  0.806901  2.847462  0.289068 -0.632489  1.072229
#
#     alpha14   alpha15   alpha16   alpha17   alpha18   alpha19   alpha20  \
# 2  1.289859  1.988012 -0.203469
# 3 -1.600400  0.608593 -0.412277
# 4  1.893524  1.602347  0.101681

# %% [markdown]
# ## 6.1. Compute similarity between products

# %%
#===============================================
# similarity in alpha matrix
#===============================================

alpha_sim = cosine_similarity(alpha_df.iloc[:, 1:])
alpha_sim = pd.DataFrame(alpha_sim)
alpha_sim.reset_index(inplace = True, drop = True)
alpha_sim.index = list(alpha_df["product_id"].values)
alpha_sim.columns = list(alpha_df["product_id"].values)
display(alpha_sim.head())
# Out:
#               1        10       100      1000     10005     10006     10017  \
# 1      1.000000 -0.011447  0.610243  0.455168  0.271690 -0.050864 -0.323460
# 10    -0.011447  1.000000  0.036718  0.163651  0.334338 -0.060544  0.256269
# 100    0.610243  0.036718  1.000000  0.088520  0.292018 -0.046460 -0.338897
# 1000   0.455168  0.163651  0.088520  1.000000  0.271276 -0.055859  0.100426
# 10005  0.271690  0.334338  0.292018  0.271276  1.000000  0.284040  0.178539
#
#           10025      1003     10032     10036     10049      1005     10054  \
# 1      0.234451  0.365623 -0.074173  0.037959  0.418443  0.448304  0.447106
# 10     0.247032  0.231619 -0.000113  0.011312 -0.105948  0.366249 -0.083356
# 100    0.222928  0.352180  0.112216  0.071458  0.478308  0.383657  0.555210
# 1000   0.290859  0.372837 -0.268119  0.049893  0.067185  0.411116  0.011693
# 10005  0.376204  0.553566 -0.187352  0.212705  0.232285  0.448414  0.053031
#
#            1006     10060     10070     10080     10082     10084     10089  \
# 1      0.080941  0.145490 -0.374280  0.439244  0.235247  0.342700  0.161279
# 10    -0.016046  0.117012  0.009678  0.166790  0.240175  0.067562  0.401079
# 100    0.189268  0.025732 -0.270502  0.490529  0.392595  0.436445  0.011937
# 1000  -0.109461  0.072555 -0.292321  0.257276  0.296234  0.045937  0.367757
# 10005 -0.078285  0.383942 -0.162820  0.574995  0.409070  0.351167  0.584314
#
#           10096     10102     10106     10107     10108     10111     10112  \
# 1      0.309880  0.605670 -0.187667  0.461931  0.017169  0.417581  0.113321
# 10     0.233288  0.175825  0.210219  0.019682 -0.060793  0.196537  0.195263
# 100    0.180939  0.695194 -0.224897  0.423718  0.181717  0.474949  0.281528
# 1000   0.332614  0.226833  0.038165  0.354710  0.058089  0.277020  0.245902
# 10005  0.552747  0.345508  0.186915  0.326405  0.123835  0.533870  0.416796
#
#           10114     10117     10121     10125     10126     10129     10130  \
# 1      0.373706  0.488711  0.102801 -0.010098  0.336447  0.343937  0.246272
# 10     0.281274  0.117968  0.266254  0.183914  0.150551  0.304300  0.209591
# 100    0.291530  0.649022  0.118014  0.202055  0.263714  0.323538  0.272818
# 1000   0.308926  0.058229  0.395630  0.024964  0.305495  0.517579  0.189837
# 10005  0.645510  0.289512  0.429329  0.251689  0.511815  0.549572  0.411032
#
#           10132     10145     10151     10163     10166      1017     10172  \
# 1     -0.490376  0.266213  0.162429  0.194122  0.314221  0.163274  0.248259
# 10    -0.005860 -0.000342 -0.021593  0.211342  0.285382  0.153547  0.120966
# 10005  0.386692  0.655010  0.674148  0.286575  0.593742  0.460014  0.563698
#
#            9799      9804      9807      9808      9810      9825      9829  \
# 1      0.384151  0.459072  0.293872 -0.210782  0.345599 -0.255146  0.478842
# 10     0.168246  0.099466  0.256370  0.180192  0.019734  0.258412  0.029814
# 100    0.359357  0.591174  0.384808 -0.221055  0.509584 -0.346348  0.648686
# 1000   0.361024  0.001122  0.375371  0.091312  0.030704  0.124933  0.106045
# 10005  0.525913  0.437941  0.539010 -0.030192  0.272865  0.207582  0.323675
#
#            9836      9837      9838      9839      9849      9852      9853  \
# 1      0.337926  0.206342  0.390846 -0.388724  0.346031  0.391597  0.603051
# 10     0.227623 -0.186114  0.141845  0.062508  0.222921 -0.033291  0.036647
# 100    0.324114  0.348357  0.598132 -0.518548  0.348279  0.506996  0.662991
# 1000   0.347969 -0.078343  0.126834  0.055187  0.380298  0.163101  0.308207
# 10005  0.509716  0.032384  0.444668 -0.331623  0.528914  0.355161  0.511183
#
#            9862      9864      9866      9871      9881      9883      9885  \
# 1      0.236751  0.268210  0.500034  0.227680  0.033257  0.414284  0.440274
# 10     0.303518  0.183066  0.070401  0.374363  0.267627  0.278979  0.257604
# 100    0.307286  0.239604  0.656964  0.241699  0.060808  0.394877  0.356208
# 1000   0.418627  0.237228  0.188883  0.428941 -0.018429  0.320583  0.461289
# 10005  0.592838  0.540351  0.420869  0.594718  0.295838  0.701896  0.594019
#
#            9886      9894      9896        99       990      9901      9906  \
# 1      0.315709  0.493945  0.316924  0.277416  0.390211  0.136517  0.268268
# 10     0.387445  0.041035  0.359812  0.327440  0.104671 -0.026405  0.297681
# 100    0.364003  0.555336  0.318081  0.358053  0.413301  0.437261  0.256336
# 1000   0.240255  0.295795  0.284968  0.338499  0.222010 -0.112786  0.393078
# 10005  0.579342  0.418808  0.521309  0.671806  0.409892  0.003361  0.624158
#
#            9913      9932      9934       994      9953      9955      9963  \
# 1      0.163742  0.378547 -0.129950  0.460556  0.565347 -0.060218  0.276861
# 10     0.381294 -0.172033  0.306253 -0.083574  0.202621  0.183726 -0.051874
# 100    0.152604  0.399159 -0.180003  0.700485  0.642124 -0.073581  0.456201
# 1000   0.317614  0.065951  0.012657  0.077343  0.162713  0.141733  0.090279
# 10005  0.518876  0.051136  0.306392  0.255689  0.406510  0.058068  0.318037
#
#            9964      9972      9996       UNK
# 1      0.365403  0.492700  0.619503  0.145059
# 10     0.290276  0.092786 -0.059146 -0.162638
# 100    0.408101  0.617614  0.544832 -0.016247
# 1000   0.368726  0.207357  0.287652  0.032670
# 10005  0.503204  0.389884  0.203729 -0.065848
#
# [5 rows x 10001 columns]

# %%
# compute similarity
def ComputeProductSimilarity(prod_id, alpha_sim, top = 5, include_prod_info = True):
    sim = alpha_sim.loc[:, prod_id]
    sim = sim.sort_values(ascending = False)
    sim = sim[1:][0:top]
    sim = pd.DataFrame({"product_id" : list(sim.index), "score": sim}, index = None)
    if include_prod_info:
        sim = products.loc[products["product_id"].isin(sim["product_id"]), ["product_id", "product_name", "aisle", "department"]]
    return sim

# %%
prod_id = "100"
products.loc[products["product_id"].isin([prod_id]), ["product_id", "product_name", "aisle", "department"]]
# Out:
#    product_id                             product_name         aisle  \
# 99  100        Peanut Butter & Strawberry Jam Sandwich  frozen meals
#
#    department
# 99  frozen

# %%
ComputeProductSimilarity(prod_id = prod_id, alpha_sim = alpha_sim, top = 10, include_prod_info = True)
# Out:
#       product_id                                             product_name  \
# 624    625        Chicken Breast Nuggets, Dinosaur Shaped
# 2976   2977       Original 100% Orange Juice with Calcium & Vitamin D
# 3775   3776       Chocolate Chip Waffles
# 10754  10755      Peanut Butter & Grape Jelly Sandwiches
# 10889  10890      Original Pancakes & Sausage On a Stick
# 11080  11081      Sweet Sliced Apples
# 19623  19624      Plain Tortilla Strips
# 19657  19658      Hash Brown Potato Patties
# 38246  38247      Men Dry Protection Cool Rush Antiperspirant & Deodorant
# 41802  41803      Uncrustables Peanut Butter & Strawberry Jam Sandwiches
#
#                             aisle     department
# 624    frozen meat seafood         frozen
# 2976   refrigerated                beverages
# 3775   frozen breakfast            frozen
# 10754  frozen dessert              frozen
# 10889  frozen breakfast            frozen
# 11080  packaged vegetables fruits  produce
# 19623  chips pretzels              snacks
# 19657  frozen appetizers sides     frozen
# 38246  deodorants                  personal care
# 41802  frozen meals                frozen

# %% [markdown]
# ----

# %% [markdown]
# ### In-class exercise

# %%
# Find most similar products to the following product
prod_id = "927"
products.loc[products["product_id"].isin([prod_id]), ["product_id", "product_name", "aisle", "department"]]
# Out:
#     product_id                             product_name      aisle department
# 926  927        Cabernet Sauvignon, Central Coast, 2011  red wines  alcohol

# %% [markdown]
# ----

# %%
# Find most similar products to the following product
prod_id = "9964"
products.loc[products["product_id"].isin([prod_id]), ["product_id", "product_name", "aisle", "department"]]
# Out:
#      product_id                                        product_name  \
# 9963  9964       Superfood Dark Chocolate and Peanut Butter Seedbar
#
#                     aisle department
# 9963  energy granola bars  snacks

# %% [markdown]
# ----

# %% [markdown]
# --------

# %% [markdown]
# # 7. Product maps using t-sne

# %% [markdown]
# ## Merge product vectors with product info

# %%
#===============================================
# column formats
#===============================================

alpha_df["product_id"] = alpha_df["product_id"].astype(str)
products["product_id"] = products["product_id"].astype(str)

# %%
#===============================================
# merge relevant columns
#===============================================

# relevant columns from product info
prod_info_cols = ["product_id", "product_name", "department", "aisle"]

# merge
word_vec_df = pd.merge(products[prod_info_cols], alpha_df, on = "product_id", how = "inner")
print(word_vec_df.shape)
# Out:
# (10000, 104)

# %%
display(word_vec_df.head(10))
# Out:
#   product_id                                    product_name    department  \
# 0  1          Chocolate Sandwich Cookies                      snacks
# 1  10         Sparkling Orange Juice & Prickly Pear Beverage  beverages
# 2  23         Organic Turkey Burgers                          meat seafood
# 3  25         Salted Caramel Lean Protein & Fiber Bar         snacks
# 4  28         Wheat Chex Cereal                               breakfast
# 5  32         Nacho Cheese White Bean Chips                   snacks
# 6  34         Peanut Butter Cereal                            breakfast
# 7  37         Noodle Soup Mix With Chicken Broth              canned goods
# 8  44         Sparkling Raspberry Seltzer                     beverages
# 9  45         European Cucumber                               produce
#
#                            aisle    alpha1    alpha2    alpha3    alpha4  \
# 4 -0.267852 -0.598348 -1.210625  1.084348 -0.227668 -1.173730 -2.396828
# 5  0.794448  0.008522 -0.625045 -0.285289  0.090588 -0.531161 -2.668699
# 6  0.054834  0.325231 -0.237459 -0.711608 -0.889252 -1.678943 -0.363623
# 7  0.343175 -0.318039  0.369610  2.463543  0.195940 -0.061671 -1.600761
# 8  0.778135 -0.222578 -1.589678 -0.412986  1.398978 -2.146440 -1.714098
# 9  0.265927 -0.401962 -1.157535  0.345173 -0.343290  2.215599 -0.776050
#
#     alpha96   alpha97   alpha98   alpha99  alpha100
# 0  0.335242  0.009643 -0.968262  1.166976 -0.811368
# 1 -0.619554  0.304297  0.652271  0.782185 -0.502302
# 2 -1.090593  0.233118 -1.112831  0.349941  0.477530
# 3 -0.036517  1.350462 -0.849876  1.739329  0.725888
# 4 -0.508914  1.902177  1.440047 -0.747673  1.009934
# 5 -1.327521  0.122297  1.211895  1.045152  0.219616
# 6 -0.040853 -0.146923  0.905060 -0.940389 -1.012895
# 7  0.433249  2.103129  1.821279  2.437232  0.027616
# 8 -0.689026  1.787528 -1.221612  0.207730  1.138871
# 9  0.437626 -1.303534  1.687353  0.928193  0.537196

# %% [markdown]
# ## 9.1. Fit t-sne

# %%
#===============================================
# fit t-sne
#===============================================

# define model
tsne = TSNE(n_components = 2, verbose = 1, perplexity = 35, n_iter = 400)

# %%
# columns to fit on
w2v_vec_names = list(word_vec_df.columns)[4:]

# fit
t0 = time.time()
tsne_fit = tsne.fit_transform(word_vec_df[w2v_vec_names])
t1 = time.time()
# Out:
# [t-SNE] Computing 106 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.129s...
# [t-SNE] Computed neighbors for 10000 samples in 29.465s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.654145
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.722626
# [t-SNE] KL divergence after 400 iterations: 2.713102

# %%
# time taken
f"Time Taken: {t1 - t0}"
# Out:
# 'Time Taken: 53.59049654006958'

# %% [markdown]
# ## T-sne component data frame

# %%
#===============================================
# create t-sne data frame
#===============================================

tsne_df = word_vec_df[["product_name", "department", "aisle"]]

# extract t-sne dimensions
tsne_df["x_tsne"] = tsne_fit[:,0]
tsne_df["y_tsne"] = tsne_fit[:,1]
print(tsne_df.describe())
# Out:
#              x_tsne        y_tsne
# count  10000.000000  10000.000000
# mean  -0.210611      0.087092
# std    11.131804     11.207771
# min   -24.733997    -25.323494
# 25%   -8.968800     -8.938216
# 50%   -0.664525      0.694044
# 75%    8.809187      8.503833
# max    24.660769     23.950001

# %%
display(tsne_df.head(20))
# Out:
#                                                product_name     department  \
# 0   Chocolate Sandwich Cookies                               snacks
# 1   Sparkling Orange Juice & Prickly Pear Beverage           beverages
# 2   Organic Turkey Burgers                                   meat seafood
# 3   Salted Caramel Lean Protein & Fiber Bar                  snacks
# 4   Wheat Chex Cereal                                        breakfast
# 5   Nacho Cheese White Bean Chips                            snacks
# 6   Peanut Butter Cereal                                     breakfast
# 7   Noodle Soup Mix With Chicken Broth                       canned goods
# 8   Sparkling Raspberry Seltzer                              beverages
# 9   European Cucumber                                        produce
# 10  Vegetarian Grain Meat Sausages Italian - 4 CT            deli
# 11  24/7 Performance Cat Litter                              pets
# 12  Banana & Sweet Potato Organic Teething Wafers            babies
# 13  Wild Albacore Tuna No Salt Added                         canned goods
# 14  100% Whole Wheat Pita Bread                              bakery
# 15  Classics Earl Grey Tea                                   beverages
# 16  Uncured Cracked Pepper Beef                              snacks
# 17  Organic Blueberry Blitz Fruit & Veggie Smoothie Mashups  babies
# 18  Organic Rice Vinegar                                     international
# 19  Local Living Butter Lettuce                              produce
#
#                             aisle     x_tsne     y_tsne
# 0   cookies cakes                  0.056011   21.625406
# 1   water seltzer sparkling water -14.405034 -0.095476
# 2   packaged poultry              -4.542143  -6.171314
# 3   energy granola bars            17.779638 -10.119496
# 4   cereal                         12.395852  10.243592
# 5   chips pretzels                -4.225415  -10.350655
# 6   cereal                        -9.870188   8.463771
# 7   soup broth bouillon            12.981880  7.321003
# 8   water seltzer sparkling water -1.908164  -12.903715
# 9   fresh vegetables              -10.826427  13.195871
# 10  tofu meat alternatives        -18.730980 -9.490770
# 11  cat food care                  16.677580  14.385563
# 12  baby food formula             -16.698444 -18.218840
# 13  canned meat seafood           -8.047843   3.957216
# 14  tortillas flat bread           6.405857   18.740616
# 15  tea                            15.630260 -15.155790
# 16  popcorn jerky                 -10.033634 -11.730324
# 17  baby food formula             -15.446750 -14.885723
# 18  asian foods                   -2.191268   0.830679
# 19  fresh vegetables              -1.415225  -11.296372

# %% [markdown]
# ## Plot with ggplot

# %%
#===============================================
# subset data for plot
#===============================================

# select only top departments
select_dept = ["produce", "babies", "beverages"]
tsne_plot_df = tsne_df.loc[tsne_df["department"].isin(select_dept), :]
print(tsne_plot_df.shape)
# Out:
# (2056, 5)

# %%
tsne_plot = ggplot(tsne_plot_df, aes(x = "x_tsne", y = "y_tsne", color = "department") ) \
        + geom_point(size = 70, alpha = 0.5) \
        + ggtitle("T-sne on product vectors") \
        + xlab(" ") + ylab(" ")
tsne_plot
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <ggplot: (-9223363299374728311)>

# %% [markdown]
# ----

# %% [markdown]
# # Class exercise - training embeddings

# %%
# Please train embeddings with the following specifcations
# embedding size = 50
# negative samples = 12
# context size = 8
# optimizer = rmsprop
# optimizer learning rate = 0.025
# batch size = 128
# epochs = 1

# %%
####### You are welcome to use the following skeleton code


# define input layers
input_target = Input((1,))
input_context = Input((1,))

# define embedding layers

# target
target = Embedding(input_dim = vocab_size, output_dim= emb_size, name = "rho")(input_target)
target = Reshape(target_shape = (emb_size, 1))(target)

# context
context = Embedding(input_dim = vocab_size, output_dim= emb_size, name = "alpha")(input_context)
context = Reshape(target_shape = (emb_size, 1))(context)

# concatenate model inputs and outputs
input_model = [input_target, input_context]

output_embeddings = Dot(axes = 1)([target, context])
output_embeddings

# resize embeddings
#output_model = Reshape((1,))(output_embeddings)
output_model = Flatten()(output_embeddings)
output_model

# complete model
output_model = Dense(1, activation = "sigmoid")(output_model)

# define as keras model
new_model = Model(inputs = input_model, outputs = output_model)

# optimizer
#### rmsprop

# compile model
# new_model.compile(optimizer = xxxx, loss = 'binary_crossentropy', metrics = ['acc'])

# model summary
# new_model.summary()
